# %% [markdown]
# THE BATTLE OF NEIGHBORHOODS

# %% [markdown]
# Introduction:
#
# New York City's demographics show that it is a large and ethnically diverse metropolis. With it's diverse culture , comes diverse food items. There are many resturants in New york City, each beloning to different categories like Chinese , Indian , Italian, French etc.
#
# In this project , we will list and visualize all major parts of New York City that has great French restaurants.

# %% [markdown]
# Data:
#
# For this project we need the following data:
#
# 1. New York City data that contains list Boroughs, Neighborhoods along with their latitude and longitude.
# 2. French resturants in each neighborhood of new york city.
# 3. GeoSpace data

# %% [markdown]
# Questions that will be answers at the end of this project :¶
# 1. What are best location in New York City for French Cuisine?
# 2. Which areas have potential French Restaurant Market?
# 3. Which all areas lack French Restaurants?
# 4. Which is the best place to stay if you prefer French Cuisine?

# %% [markdown]
# Methodology:
#
# 1.We begin by collecting the New York city data from "https://cocl.us/new_york_dataset".
# 2.We will find all venues for each neighborhood using FourSquare API.
# 3.We will then filter out all Indian Restuarant venues.
# 4.Next using FourSquare API, we will find the Ratings, Tips, and Like count for all the Indian Resturants.
# 5.Next we will sort the data keeping Ratings as the constraint.
# 6.Finally, we will visualize the Ranking of neighborhoods using python's Folium library.

# %% [markdown]
# Lets Start by importing the required Libraries.

# %%
import sys
! pip install geocoder
! pip install folium
! pip install SomePackage
! pip install numpy
! pip install BeautifulSoup4
! pip install wikipedia
! pip install bs4
! pip install IPython
! pip install lxml
! pip install Nominatim
! pip install geopy

print('Packages installed.')
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 10.0 MB/s eta 0:00:01
# Requirement already satisfied: click in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2020.12.5)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 6.7 MB/s  eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting SomePackage
#   Downloading somepackage-1.2.3.tar.gz (8.6 kB)
# Building wheels for collected packages: SomePackage
#   Building wheel for SomePackage (setup.py) ... done
#   Created wheel for SomePackage: filename=somepackage-1.2.3-py3-none-any.whl size=9289 sha256=4fdcaa61de4a34a6afa0d2335a98d5349b25c37fe60a37bc12fd20624dda42e9
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/ac/60/3d/195deb8ad5768f322df5510ff4f686233d29243c709dc563ba
# Successfully built SomePackage
# Installing collected packages: SomePackage
# Successfully installed SomePackage-1.2.3
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.18.5)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from wikipedia) (4.9.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from wikipedia) (2.24.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4->wikipedia) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.9)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11685 sha256=78548f2774daccec9700942ce753d14764fe4da658a1c796a8441946d51804bb
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.0.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=8daddc420bdec228a32c7a832939d4e6f98ea8cbebdf6a4fdd30c5139af3cc11
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: IPython in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (7.15.0)
# Requirement already satisfied: backcall in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (0.17.1)
# Requirement already satisfied: pickleshare in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (4.4.2)
# Requirement already satisfied: pygments in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (4.3.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (3.0.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from IPython) (47.3.1.post20200622)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->IPython) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jedi>=0.10->IPython) (0.7.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from traitlets>=4.2->IPython) (0.2.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from traitlets>=4.2->IPython) (1.15.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.4)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.6.3)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting Nominatim
#   Downloading nominatim-0.1.tar.gz (1.7 kB)
# Building wheels for collected packages: Nominatim
#   Building wheel for Nominatim (setup.py) ... done
#   Created wheel for Nominatim: filename=nominatim-0.1-py3-none-any.whl size=2363 sha256=b3d2c80feae3f35178840ddf6c190781c26e91fb8e17420a12cfd1eeb05efed3
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/37/00/9e/d904c390bfb174830ad3dcfd62af5544cee7d88bed4f8acedd
# Successfully built Nominatim
# Installing collected packages: Nominatim
# Successfully installed Nominatim-0.1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Packages installed.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium

import os
import folium # map rendering library
# Matplotlib and associated plotting modules

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as mp
import re
import csv
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now we define a function to get the geocodes i.e latitude and longitude of a given location using geopy.

# %%
def geo_location(address):
    # get geo location of address
    address ='New York,USA'
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinate of New York are {}, {}.'.format(latitude, longitude))

# %% [markdown]
# We define a function to intract with FourSquare API and get top 100 venues within a radius of 1000 metres for a given latitude and longitude. Below function will return us the venue id , venue name and category.

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = '1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1'#
    CLIENT_SECRET = 'NU3QOJRDYYVJN0125XOZDZFQGLYVYSC5R5IEGBHXHL0SFFRO'#
    VERSION = '20180604'# 
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# Now we will define a function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking.

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = '1CVX0P22PGNHR2GYDNEIYSSE5UZHVOGVTVADWQXJ5NF5BKJ1'#  
    CLIENT_SECRET = 'NU3QOJRDYYVJN0125XOZDZFQGLYVYSC5R5IEGBHXHL0SFFRO'#  
    VERSION = '20180604'#
    
   #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# Now we define a funtion to get the new york city data such as Boroughs, Neighborhoods along with their latitude and longitude.

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %% [markdown]
# We will call the above funtion to get the new york city data.

# %%
new_york_data=get_new_york_data()
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %% [markdown]
# The above result shows that there are 306 different Neighborhoods in New York.¶

# %% [markdown]
# Now let create a BAR PLOT to show different Neighborhoods in New York.

# %%
plt.figure(figsize=(8,5), dpi = 100)
# title
plt.title('Number of Neighborhood for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 12)
#On y-axis
plt.ylabel('No.of Neighborhood', fontsize=12)
#giving a bar plot
new_york_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# From the above Plot, we can see the Queens has the highest number of neighborhoods.

# %% [markdown]
# Next we will collect French restaurants for each Neighborhood.

# %%
# prepare neighborhood list that contains french restaurant
column_names=['Borough', 'Neighborhood', 'ID','Name']
french_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    french_resturants=venues[venues['Category']=='French Restaurant']   
    print('(',count,'/',len(new_york_data),')','French Resturants in '+Neighborhood+', '+Borough+':'+str(len(french_resturants)))
    print(row)
    for resturant_detail in french_resturants.values.tolist():
        id, name , category=resturant_detail
        french_rest_ny = french_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name}, ignore_index=True)
        count+=1
# Out:
# ( 1 / 306 ) French Resturants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 1 / 306 ) French Resturants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 1 / 306 ) French Resturants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 1 / 306 ) French Resturants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 1 / 306 ) French Resturants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 1 / 306 ) French Resturants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 1 / 306 ) French Resturants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 1 / 306 ) French Resturants in Woodlawn, Bronx:0
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 1 / 306 ) French Resturants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 1 / 306 ) French Resturants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 1 / 306 ) French Resturants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 1 / 306 ) French Resturants in Pelham Parkway, Bronx:0
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 1 / 306 ) French Resturants in City Island, Bronx:1
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 2 / 306 ) French Resturants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 2 / 306 ) French Resturants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 2 / 306 ) French Resturants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 2 / 306 ) French Resturants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 2 / 306 ) French Resturants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 2 / 306 ) French Resturants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 2 / 306 ) French Resturants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 2 / 306 ) French Resturants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 2 / 306 ) French Resturants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 2 / 306 ) French Resturants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 2 / 306 ) French Resturants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 2 / 306 ) French Resturants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 2 / 306 ) French Resturants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 2 / 306 ) French Resturants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 2 / 306 ) French Resturants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 2 / 306 ) French Resturants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 2 / 306 ) French Resturants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 2 / 306 ) French Resturants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 2 / 306 ) French Resturants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 2 / 306 ) French Resturants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 2 / 306 ) French Resturants in Morris Park, Bronx:0
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 2 / 306 ) French Resturants in Belmont, Bronx:0
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 2 / 306 ) French Resturants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 2 / 306 ) French Resturants in North Riverdale, Bronx:0
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 2 / 306 ) French Resturants in Pelham Bay, Bronx:0
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 2 / 306 ) French Resturants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 2 / 306 ) French Resturants in Edgewater Park, Bronx:0
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 2 / 306 ) French Resturants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 2 / 306 ) French Resturants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 2 / 306 ) French Resturants in Pelham Gardens, Bronx:0
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 2 / 306 ) French Resturants in Concourse, Bronx:0
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 2 / 306 ) French Resturants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 2 / 306 ) French Resturants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 2 / 306 ) French Resturants in Bay Ridge, Brooklyn:0
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 2 / 306 ) French Resturants in Bensonhurst, Brooklyn:0
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 2 / 306 ) French Resturants in Sunset Park, Brooklyn:0
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 2 / 306 ) French Resturants in Greenpoint, Brooklyn:3
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 5 / 306 ) French Resturants in Gravesend, Brooklyn:0
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 5 / 306 ) French Resturants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 5 / 306 ) French Resturants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 5 / 306 ) French Resturants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 5 / 306 ) French Resturants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 5 / 306 ) French Resturants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 5 / 306 ) French Resturants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 5 / 306 ) French Resturants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 5 / 306 ) French Resturants in Windsor Terrace, Brooklyn:1
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 6 / 306 ) French Resturants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 6 / 306 ) French Resturants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 6 / 306 ) French Resturants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 6 / 306 ) French Resturants in Bushwick, Brooklyn:2
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 8 / 306 ) French Resturants in Bedford Stuyvesant, Brooklyn:2
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 10 / 306 ) French Resturants in Brooklyn Heights, Brooklyn:1
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 11 / 306 ) French Resturants in Cobble Hill, Brooklyn:1
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 12 / 306 ) French Resturants in Carroll Gardens, Brooklyn:2
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 14 / 306 ) French Resturants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 14 / 306 ) French Resturants in Gowanus, Brooklyn:1
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 15 / 306 ) French Resturants in Fort Greene, Brooklyn:1
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 16 / 306 ) French Resturants in Park Slope, Brooklyn:0
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 16 / 306 ) French Resturants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 16 / 306 ) French Resturants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 16 / 306 ) French Resturants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 16 / 306 ) French Resturants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 16 / 306 ) French Resturants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 16 / 306 ) French Resturants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 16 / 306 ) French Resturants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 16 / 306 ) French Resturants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 16 / 306 ) French Resturants in Bath Beach, Brooklyn:0
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 16 / 306 ) French Resturants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 16 / 306 ) French Resturants in Dyker Heights, Brooklyn:0
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 16 / 306 ) French Resturants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 16 / 306 ) French Resturants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 16 / 306 ) French Resturants in Clinton Hill, Brooklyn:1
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 17 / 306 ) French Resturants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 17 / 306 ) French Resturants in Downtown, Brooklyn:3
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 20 / 306 ) French Resturants in Boerum Hill, Brooklyn:2
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 22 / 306 ) French Resturants in Prospect Lefferts Gardens, Brooklyn:0
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 22 / 306 ) French Resturants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 22 / 306 ) French Resturants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 22 / 306 ) French Resturants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 22 / 306 ) French Resturants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 22 / 306 ) French Resturants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 22 / 306 ) French Resturants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 22 / 306 ) French Resturants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 22 / 306 ) French Resturants in North Side, Brooklyn:1
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 23 / 306 ) French Resturants in South Side, Brooklyn:0
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 23 / 306 ) French Resturants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 23 / 306 ) French Resturants in Fort Hamilton, Brooklyn:0
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 23 / 306 ) French Resturants in Chinatown, Manhattan:1
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 24 / 306 ) French Resturants in Washington Heights, Manhattan:0
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 24 / 306 ) French Resturants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 24 / 306 ) French Resturants in Hamilton Heights, Manhattan:0
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 24 / 306 ) French Resturants in Manhattanville, Manhattan:1
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 25 / 306 ) French Resturants in Central Harlem, Manhattan:3
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 28 / 306 ) French Resturants in East Harlem, Manhattan:1
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 29 / 306 ) French Resturants in Upper East Side, Manhattan:1
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 30 / 306 ) French Resturants in Yorkville, Manhattan:1
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 31 / 306 ) French Resturants in Lenox Hill, Manhattan:2
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 33 / 306 ) French Resturants in Roosevelt Island, Manhattan:1
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 34 / 306 ) French Resturants in Upper West Side, Manhattan:0
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 34 / 306 ) French Resturants in Lincoln Square, Manhattan:5
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 39 / 306 ) French Resturants in Clinton, Manhattan:2
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 41 / 306 ) French Resturants in Midtown, Manhattan:1
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 42 / 306 ) French Resturants in Murray Hill, Manhattan:1
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 43 / 306 ) French Resturants in Chelsea, Manhattan:3
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 46 / 306 ) French Resturants in Greenwich Village, Manhattan:2
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 48 / 306 ) French Resturants in East Village, Manhattan:0
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 48 / 306 ) French Resturants in Lower East Side, Manhattan:2
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 50 / 306 ) French Resturants in Tribeca, Manhattan:3
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 53 / 306 ) French Resturants in Little Italy, Manhattan:1
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 54 / 306 ) French Resturants in Soho, Manhattan:2
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 56 / 306 ) French Resturants in West Village, Manhattan:3
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 59 / 306 ) French Resturants in Manhattan Valley, Manhattan:1
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 60 / 306 ) French Resturants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 60 / 306 ) French Resturants in Gramercy, Manhattan:0
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 60 / 306 ) French Resturants in Battery Park City, Manhattan:1
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 61 / 306 ) French Resturants in Financial District, Manhattan:1
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 62 / 306 ) French Resturants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 62 / 306 ) French Resturants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 62 / 306 ) French Resturants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 62 / 306 ) French Resturants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 62 / 306 ) French Resturants in Howard Beach, Queens:0
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 62 / 306 ) French Resturants in Corona, Queens:0
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 62 / 306 ) French Resturants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 62 / 306 ) French Resturants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 62 / 306 ) French Resturants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 62 / 306 ) French Resturants in Flushing, Queens:0
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 62 / 306 ) French Resturants in Long Island City, Queens:0
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 62 / 306 ) French Resturants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 62 / 306 ) French Resturants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 62 / 306 ) French Resturants in Maspeth, Queens:0
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 62 / 306 ) French Resturants in Ridgewood, Queens:0
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 62 / 306 ) French Resturants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 62 / 306 ) French Resturants in Rego Park, Queens:0
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 62 / 306 ) French Resturants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 62 / 306 ) French Resturants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 62 / 306 ) French Resturants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 62 / 306 ) French Resturants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 62 / 306 ) French Resturants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 62 / 306 ) French Resturants in Bayside, Queens:0
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 62 / 306 ) French Resturants in Auburndale, Queens:0
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 62 / 306 ) French Resturants in Little Neck, Queens:1
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 63 / 306 ) French Resturants in Douglaston, Queens:1
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 64 / 306 ) French Resturants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 64 / 306 ) French Resturants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 64 / 306 ) French Resturants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 64 / 306 ) French Resturants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 64 / 306 ) French Resturants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 64 / 306 ) French Resturants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 64 / 306 ) French Resturants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 64 / 306 ) French Resturants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 64 / 306 ) French Resturants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 64 / 306 ) French Resturants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 64 / 306 ) French Resturants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 64 / 306 ) French Resturants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 64 / 306 ) French Resturants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 64 / 306 ) French Resturants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 64 / 306 ) French Resturants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 64 / 306 ) French Resturants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 64 / 306 ) French Resturants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 64 / 306 ) French Resturants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 64 / 306 ) French Resturants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 64 / 306 ) French Resturants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 64 / 306 ) French Resturants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 64 / 306 ) French Resturants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 64 / 306 ) French Resturants in Arverne, Queens:1
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 65 / 306 ) French Resturants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 65 / 306 ) French Resturants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 65 / 306 ) French Resturants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 65 / 306 ) French Resturants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 65 / 306 ) French Resturants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 65 / 306 ) French Resturants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 65 / 306 ) French Resturants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 65 / 306 ) French Resturants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 65 / 306 ) French Resturants in Ravenswood, Queens:1
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 66 / 306 ) French Resturants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 66 / 306 ) French Resturants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 66 / 306 ) French Resturants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 66 / 306 ) French Resturants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 66 / 306 ) French Resturants in Rockaway Park, Queens:1
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 67 / 306 ) French Resturants in Somerville, Queens:1
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 68 / 306 ) French Resturants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 68 / 306 ) French Resturants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 68 / 306 ) French Resturants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 68 / 306 ) French Resturants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 68 / 306 ) French Resturants in St. George, Staten Island:0
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 68 / 306 ) French Resturants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 68 / 306 ) French Resturants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 68 / 306 ) French Resturants in Rosebank, Staten Island:0
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 68 / 306 ) French Resturants in West Brighton, Staten Island:0
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 68 / 306 ) French Resturants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 68 / 306 ) French Resturants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 68 / 306 ) French Resturants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 68 / 306 ) French Resturants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 68 / 306 ) French Resturants in Mariner's Harbor, Staten Island:0
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 68 / 306 ) French Resturants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 68 / 306 ) French Resturants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 68 / 306 ) French Resturants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 68 / 306 ) French Resturants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 68 / 306 ) French Resturants in New Dorp, Staten Island:1
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 69 / 306 ) French Resturants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 69 / 306 ) French Resturants in Great Kills, Staten Island:0
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 69 / 306 ) French Resturants in Eltingville, Staten Island:0
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 69 / 306 ) French Resturants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 69 / 306 ) French Resturants in Woodrow, Staten Island:0
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 69 / 306 ) French Resturants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 69 / 306 ) French Resturants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 69 / 306 ) French Resturants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 69 / 306 ) French Resturants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 69 / 306 ) French Resturants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 69 / 306 ) French Resturants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 69 / 306 ) French Resturants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 69 / 306 ) French Resturants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 69 / 306 ) French Resturants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 69 / 306 ) French Resturants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 69 / 306 ) French Resturants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 69 / 306 ) French Resturants in Arrochar, Staten Island:0
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 69 / 306 ) French Resturants in Grasmere, Staten Island:0
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 69 / 306 ) French Resturants in Old Town, Staten Island:0
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 69 / 306 ) French Resturants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 69 / 306 ) French Resturants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 69 / 306 ) French Resturants in Grant City, Staten Island:1
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 70 / 306 ) French Resturants in New Dorp Beach, Staten Island:0
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 70 / 306 ) French Resturants in Bay Terrace, Staten Island:0
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 70 / 306 ) French Resturants in Huguenot, Staten Island:0
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 70 / 306 ) French Resturants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 70 / 306 ) French Resturants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 70 / 306 ) French Resturants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 70 / 306 ) French Resturants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 70 / 306 ) French Resturants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 70 / 306 ) French Resturants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 70 / 306 ) French Resturants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 70 / 306 ) French Resturants in Chelsea, Staten Island:0
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 70 / 306 ) French Resturants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 70 / 306 ) French Resturants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 70 / 306 ) French Resturants in Carnegie Hill, Manhattan:2
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 72 / 306 ) French Resturants in Noho, Manhattan:2
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 74 / 306 ) French Resturants in Civic Center, Manhattan:4
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 78 / 306 ) French Resturants in Midtown South, Manhattan:0
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 78 / 306 ) French Resturants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 78 / 306 ) French Resturants in Shore Acres, Staten Island:0
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 78 / 306 ) French Resturants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 78 / 306 ) French Resturants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 78 / 306 ) French Resturants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 78 / 306 ) French Resturants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 78 / 306 ) French Resturants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 78 / 306 ) French Resturants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 78 / 306 ) French Resturants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 78 / 306 ) French Resturants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 78 / 306 ) French Resturants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 78 / 306 ) French Resturants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 78 / 306 ) French Resturants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 78 / 306 ) French Resturants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 78 / 306 ) French Resturants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 78 / 306 ) French Resturants in Astoria Heights, Queens:0
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 78 / 306 ) French Resturants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 78 / 306 ) French Resturants in Concourse Village, Bronx:0
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 78 / 306 ) French Resturants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 78 / 306 ) French Resturants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 78 / 306 ) French Resturants in Sutton Place, Manhattan:3
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 81 / 306 ) French Resturants in Hunters Point, Queens:1
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 82 / 306 ) French Resturants in Turtle Bay, Manhattan:2
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 84 / 306 ) French Resturants in Tudor City, Manhattan:2
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 86 / 306 ) French Resturants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 86 / 306 ) French Resturants in Flatiron, Manhattan:0
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 86 / 306 ) French Resturants in Sunnyside Gardens, Queens:1
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 87 / 306 ) French Resturants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 87 / 306 ) French Resturants in Fulton Ferry, Brooklyn:0
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 87 / 306 ) French Resturants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 87 / 306 ) French Resturants in Weeksville, Brooklyn:1
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 88 / 306 ) French Resturants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 88 / 306 ) French Resturants in Dumbo, Brooklyn:0
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 88 / 306 ) French Resturants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 88 / 306 ) French Resturants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 88 / 306 ) French Resturants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 88 / 306 ) French Resturants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 88 / 306 ) French Resturants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 88 / 306 ) French Resturants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 88 / 306 ) French Resturants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 88 / 306 ) French Resturants in Prince's Bay, Staten Island:0
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 88 / 306 ) French Resturants in Lighthouse Hill, Staten Island:0
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 88 / 306 ) French Resturants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 88 / 306 ) French Resturants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 88 / 306 ) French Resturants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 88 / 306 ) French Resturants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 88 / 306 ) French Resturants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 88 / 306 ) French Resturants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 88 / 306 ) French Resturants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 88 / 306 ) French Resturants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 88 / 306 ) French Resturants in Hudson Yards, Manhattan:1
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 89 / 306 ) French Resturants in Hammels, Queens:1
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 90 / 306 ) French Resturants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 90 / 306 ) French Resturants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 90 / 306 ) French Resturants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %% [markdown]
# Now that we have got all the French resturants in new york city ,then analyze it.

# %%
french_rest_ny.head()
# Out:
#     Borough     Neighborhood                        ID           Name
# 0     Bronx      City Island  4d7aa83ee540f04d66ba16dc      Bistro SK
# 1  Brooklyn       Greenpoint  5bf358689fca56002c251a87        Citroën
# 2  Brooklyn       Greenpoint  58fd34584382ab70ad90083e  Chez Ma Tante
# 3  Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0       Le Gamin
# 4  Brooklyn  Windsor Terrace  4e7d174cb6340a4da75a2cca     Le Paddock

# %%
french_rest_ny.shape
# Out:
# (89, 4)

# %% [markdown]
# From the above result, we see that there are 89 French Resturants across New York City.

# %% [markdown]
# Now let create a BAR PLOT to show Number of French Resturants for each Borough in New York City.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of French Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 12)
#On y-axis
plt.ylabel('No.of French Resturants', fontsize=12)
#giving a bar plot
french_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# From the Plot, we can see that MANHATTHAN has highest number of French resturants.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of French Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 12)
#On y-axis
plt.ylabel('No.of French Resturants', fontsize=12)
#giving a bar plot
french_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
french_rest_ny[french_rest_ny['Neighborhood']=='Lincoln Square']
# Out:
#       Borough    Neighborhood                        ID  \
# 33  Manhattan  Lincoln Square  414ccc00f964a520d21c1fe3
# 34  Manhattan  Lincoln Square  478cd1f3f964a520444d1fe3
# 35  Manhattan  Lincoln Square  3fd66200f964a520bee91ee3
# 36  Manhattan  Lincoln Square  49e7897ff964a520b6641fe3
# 37  Manhattan  Lincoln Square  41f19780f964a520101f1fe3
#
#                          Name
# 33            Cafe Luxembourg
# 34                 Bar Boulud
# 35               Jean-Georges
# 36  Nougatine at Jean Georges
# 37                     Per Se

# %% [markdown]
# We can see that, Lincoln Square in Manhattan has the highest number of French Resturants with a total count of 5.¶

# %% [markdown]
# Now we will get the ranking of each resturant for further analysis.

# %%
# prepare neighborhood list that contains french resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
french_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in french_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row

    # prepare neighborhood list that contains french resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
french_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in french_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except (KeyError) as e:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(french_rest_ny),')','processed')
    french_rest_stats_ny = french_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID       Name  Likes  Rating  Tips
# 0  4d7aa83ee540f04d66ba16dc  Bistro SK     12     7.5     7
# ( 1 / 89 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5bf358689fca56002c251a87  Citroën     25     8.4     3
# ( 2 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  58fd34584382ab70ad90083e  Chez Ma Tante    224     9.1    60
# ( 3 / 89 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  4bcf1883c564ef3ba33beff0  Le Gamin    161     7.8    73
# ( 4 / 89 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4e7d174cb6340a4da75a2cca  Le Paddock    141     8.8    56
# ( 5 / 89 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  55e47d26498e44d12c7c004e  Le Garage     99     8.3    25
# ( 6 / 89 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  50b99e4ae4b0c22ba9633dfd  Mominette    342     8.2    81
# ( 7 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5b5cb5468ad62e002cdc39d5  Madame Poupon      9     8.3     5
# ( 8 / 89 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  5003007de4b06d50188aa593  Le Paris Dakar    148     8.6    41
# ( 9 / 89 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  4f7f8b86e4b088077df30175  Chez Moi    204     8.5    76
# ( 10 / 89 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  4f7f8b86e4b088077df30175  Chez Moi    204     8.5    76
# ( 11 / 89 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  5df42352f93ca9000762ff64  Bar Bête     25     8.6     5
# ( 12 / 89 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4e2ca88afa76bbf847e6886c  Jolie Bistro    217     8.2    78
# ( 13 / 89 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  51e7e612498e001aa73959dd  Olivier Bistro    109     7.8    39
# ( 14 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5250553911d262bb0c732ee8  Cafe Paulette    220     8.6    53
# ( 15 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5250553911d262bb0c732ee8  Cafe Paulette    220     8.6    53
# ( 16 / 89 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  530931a5498e4079544a5f13  French Louie    574     9.0   115
# ( 17 / 89 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4d20bc3af7a9a143bcab2f9f  The Little Sweet Café     69     7.9    32
# ( 18 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5250553911d262bb0c732ee8  Cafe Paulette    220     8.6    53
# ( 19 / 89 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  530931a5498e4079544a5f13  French Louie    574     9.0   115
# ( 20 / 89 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  3fd66200f964a52058f11ee3  Bar Tabac    452     8.2   211
# ( 21 / 89 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  4554c3b0f964a520113d1fe3  Juliette    782     8.4   276
# ( 22 / 89 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  558ddcbe498e892dbe0d3a8b  Les Enfants de Bohème     90     8.6    19
# ( 23 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  511a937ee88968b8acbba54b  Maison Harlem    289     8.6    88
# ( 24 / 89 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  4b80389ff964a520e95d30e3  Yatenga    104     8.6    62
# ( 25 / 89 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  59cc6158c0af57432b9fd02b  Renaissance Harlem     16     8.2     3
# ( 26 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  511a937ee88968b8acbba54b  Maison Harlem    289     8.6    88
# ( 27 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  553c1b00498e7eb81316bf1b  Mountain Bird     80     8.9    18
# ( 28 / 89 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  4408540af964a52055301fe3  Orsay    153     8.3    46
# ( 29 / 89 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  467ffefcf964a52019481fe3  Cafe D'Alsace    528     8.8   174
# ( 30 / 89 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  4408540af964a52055301fe3  Orsay    153     8.3    46
# ( 31 / 89 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4d8e49c36174a0935ff2c4e3  Le Moulin A Cafe    159     8.5    64
# ( 32 / 89 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4d8e49c36174a0935ff2c4e3  Le Moulin A Cafe    159     8.5    64
# ( 33 / 89 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  414ccc00f964a520d21c1fe3  Cafe Luxembourg    304     8.6   100
# ( 34 / 89 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  478cd1f3f964a520444d1fe3  Bar Boulud    383     8.0   183
# ( 35 / 89 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  3fd66200f964a520bee91ee3  Jean-Georges    553     9.0   284
# ( 36 / 89 ) processed
#                          ID                       Name  Likes  Rating  Tips
# 0  49e7897ff964a520b6641fe3  Nougatine at Jean Georges    278     8.8   102
# ( 37 / 89 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  41f19780f964a520101f1fe3  Per Se    393     8.8   192
# ( 38 / 89 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  3fd66200f964a5208de91ee3  Chez Josephine    112     8.2    56
# ( 39 / 89 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  3fd66200f964a520b4e81ee3  Marseille    256     8.1   112
# ( 40 / 89 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  5552087d498eb30c149f785a  Gabriel Kreuther    155     9.0    76
# ( 41 / 89 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4c408f9e6c1a95216050b96a  Le Parisien    138     8.5    67
# ( 42 / 89 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5dcf67e642c0140007488570  Loulou     18     8.5     3
# ( 43 / 89 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  59c724adb3d8e220e8c71ab8  Intersect By Lexus     65     8.8    12
# ( 44 / 89 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5ce5b1f1f5e9d7002c4ad547  Pastis    144     9.1    20
# ( 45 / 89 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  3fd66200f964a52006e61ee3  Raoul's Restaurant    392     9.1   154
# ( 46 / 89 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  3fd66200f964a52070e91ee3  Balthazar   3042     8.9  1049
# ( 47 / 89 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  5303f306498ebbca8f7e1158  Le French Diner     69     9.0    22
# ( 48 / 89 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  556b8dc2498eb674c015c301  Wildair    270     8.7    74
# ( 49 / 89 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  5abc33ccad17896edaca3d61  Frenchette    186     8.7    35
# ( 50 / 89 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  566c9c87498ef09a2940e605  Maman    296     8.6    73
# ( 51 / 89 ) processed
# No data available for id= 3fd66200f964a52083e61ee3
# ( 52 / 89 ) processed
# No data available for id= 3fd66200f964a52070e91ee3
# ( 53 / 89 ) processed
# No data available for id= 3fd66200f964a52070e91ee3
# ( 54 / 89 ) processed
# No data available for id= 3fd66200f964a52006e61ee3
# ( 55 / 89 ) processed
# No data available for id= 4d0bf7e3f29c236ac675bfe7
# ( 56 / 89 ) processed
# No data available for id= 4abe33aaf964a520f18b20e3
# ( 57 / 89 ) processed
# No data available for id= 5ce5b1f1f5e9d7002c4ad547
# ( 58 / 89 ) processed
# No data available for id= 44e86a78f964a5209c371fe3
# ( 59 / 89 ) processed
# No data available for id= 5a47a5e4e679bc7b226989ca
# ( 60 / 89 ) processed
# No data available for id= 5a47a5e4e679bc7b226989ca
# ( 61 / 89 ) processed
# No data available for id= 4b428a19f964a52002d625e3
# ( 62 / 89 ) processed
# No data available for id= 4b428a19f964a52002d625e3
# ( 63 / 89 ) processed
# No data available for id= 5f78edd788b0165c622d34f5
# ( 64 / 89 ) processed
# No data available for id= 467fc553f964a52016481fe3
# ( 65 / 89 ) processed
# No data available for id= 4f71ce9de4b0a89fa4b084de
# ( 66 / 89 ) processed
# No data available for id= 5f78edd788b0165c622d34f5
# ( 67 / 89 ) processed
# No data available for id= 4da08c63bb206ea8da50defd
# ( 68 / 89 ) processed
# No data available for id= 4da08c63bb206ea8da50defd
# ( 69 / 89 ) processed
# No data available for id= 4b9d2218f964a5207e9236e3
# ( 70 / 89 ) processed
# No data available for id= 467ffefcf964a52019481fe3
# ( 71 / 89 ) processed
# No data available for id= 5303f306498ebbca8f7e1158
# ( 72 / 89 ) processed
# No data available for id= 3fd66200f964a5202de51ee3
# ( 73 / 89 ) processed
# No data available for id= 534c9d7b498e1bdd443a40e1
# ( 74 / 89 ) processed
# No data available for id= 3fd66200f964a52083e61ee3
# ( 75 / 89 ) processed
# No data available for id= 566c9c87498ef09a2940e605
# ( 76 / 89 ) processed
# No data available for id= 5abc33ccad17896edaca3d61
# ( 77 / 89 ) processed
# No data available for id= 4b70825df964a520e01e2de3
# ( 78 / 89 ) processed
# No data available for id= 437bc800f964a520a22a1fe3
# ( 79 / 89 ) processed
# No data available for id= 522b6da511d2a6f8f7a6798f
# ( 80 / 89 ) processed
# No data available for id= 4a216706f964a520e27c1fe3
# ( 81 / 89 ) processed
# No data available for id= 4a64fda8f964a52023c71fe3
# ( 82 / 89 ) processed
# No data available for id= 5143a58229a6639d6cfd525c
# ( 83 / 89 ) processed
# No data available for id= 533d99c8498e4ed0ad9db108
# ( 84 / 89 ) processed
# No data available for id= 4c408f9e6c1a95216050b96a
# ( 85 / 89 ) processed
# No data available for id= 57f57d5dcd1047e759ea8838
# ( 86 / 89 ) processed
# No data available for id= 439591fcf964a5208c2b1fe3
# ( 87 / 89 ) processed
# No data available for id= 3fd66200f964a5208de91ee3
# ( 88 / 89 ) processed
# No data available for id= 5f78edd788b0165c622d34f5
# ( 89 / 89 ) processed

# %%
french_rest_stats_ny.head()
# Out:
#     Borough     Neighborhood                        ID           Name Likes  \
# 0     Bronx      City Island  4d7aa83ee540f04d66ba16dc      Bistro SK    12
# 1  Brooklyn       Greenpoint  5bf358689fca56002c251a87        Citroën    25
# 2  Brooklyn       Greenpoint  58fd34584382ab70ad90083e  Chez Ma Tante   224
# 3  Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0       Le Gamin   161
# 4  Brooklyn  Windsor Terrace  4e7d174cb6340a4da75a2cca     Le Paddock   141
#
#    Rating Tips
# 0     7.5    7
# 1     8.4    3
# 2     9.1   60
# 3     7.8   73
# 4     8.8   56

# %%
french_rest_stats_ny.shape
# Out:
# (89, 7)

# %%
french_rest_ny.shape
# Out:
# (89, 4)

# %% [markdown]
# Now that we got data for all resturants Now lets save this data to a csv sheet. In case we by mistake modify it. As the number of calls to get details for venue are premium call and have limit of 500 per day, we will refer to saved data sheet csv if required.

# %%
french_rest_stats_ny.to_csv('french_rest_stats_ny.csv', index=False)

# %% [markdown]
# Lets verify the data from saved csv file.

# %%
french_rest_stats_ny_csv=pd.read_csv('french_rest_stats_ny.csv')

# %%
french_rest_stats_ny_csv.shape
# Out:
# (89, 7)

# %%
french_rest_stats_ny_csv.head()
# Out:
#     Borough     Neighborhood                        ID           Name  Likes  \
# 0     Bronx      City Island  4d7aa83ee540f04d66ba16dc      Bistro SK     12
# 1  Brooklyn       Greenpoint  5bf358689fca56002c251a87        Citroën     25
# 2  Brooklyn       Greenpoint  58fd34584382ab70ad90083e  Chez Ma Tante    224
# 3  Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0       Le Gamin    161
# 4  Brooklyn  Windsor Terrace  4e7d174cb6340a4da75a2cca     Le Paddock    141
#
#    Rating  Tips
# 0     7.5     7
# 1     8.4     3
# 2     9.1    60
# 3     7.8    73
# 4     8.8    56

# %%
french_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       89 non-null     object
#  1   Neighborhood  89 non-null     object
#  2   ID            89 non-null     object
#  3   Name          89 non-null     object
#  4   Likes         89 non-null     object
#  5   Rating        89 non-null     float64
#  6   Tips          89 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.0+ KB

# %% [markdown]
# The Data type of 'Likes' and 'Tips' are of type 'String'. we will convert them into type 'Float' for further analysis.

# %%
french_rest_stats_ny['Likes']=french_rest_stats_ny['Likes'].astype('float64')
french_rest_stats_ny['Tips']=french_rest_stats_ny['Tips'].astype('float64')

# %%
french_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       89 non-null     object
#  1   Neighborhood  89 non-null     object
#  2   ID            89 non-null     object
#  3   Name          89 non-null     object
#  4   Likes         89 non-null     float64
#  5   Rating        89 non-null     float64
#  6   Tips          89 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 5.0+ KB

# %% [markdown]
# Now we will find the French restuarants with Maximum Likes, Maximum Ratings and Maximum Tips.

# %%
# Resturant with maximum Likes
french_rest_stats_ny.iloc[french_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood           Greenwich Village
# ID              3fd66200f964a52070e91ee3
# Name                           Balthazar
# Likes                               3042
# Rating                               8.9
# Tips                                1049
# Name: 46, dtype: object

# %%
# Resturant with maximum Rating
french_rest_stats_ny.iloc[french_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                         Brooklyn
# Neighborhood                  Greenpoint
# ID              58fd34584382ab70ad90083e
# Name                       Chez Ma Tante
# Likes                                224
# Rating                               9.1
# Tips                                  60
# Name: 2, dtype: object

# %%
# Resturant with maximum Tips
french_rest_stats_ny.iloc[french_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood           Greenwich Village
# ID              3fd66200f964a52070e91ee3
# Name                           Balthazar
# Likes                               3042
# Rating                               8.9
# Tips                                1049
# Name: 46, dtype: object

# %% [markdown]
# Next lets visualize neighborhood with maximum average rating of resturants.

# %%
ny_neighborhood_stats=french_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#          Neighborhood  Average Rating
# 35            Midtown            9.00
# 24  Greenwich Village            9.00
# 18        East Harlem            8.90
# 32    Lower East Side            8.85
# 54          Yorkville            8.80
# 53    Windsor Terrace            8.80
# 9             Chelsea            8.80
# 29     Lincoln Square            8.64
# 14       Clinton Hill            8.60
# 34     Manhattanville            8.60

# %% [markdown]
# Above are the top neighborhoods with top average rating of French restaurants

# %% [markdown]
# Similarly we will find the average rating of French restaurants for each Borough.

# %%
ny_borough_stats=french_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#          Borough  Average Rating
# 1       Brooklyn        8.063636
# 0          Bronx        7.500000
# 2      Manhattan        4.550909
# 3         Queens        0.000000
# 4  Staten Island        0.000000

# %% [markdown]
# Let's Visualize it.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of French Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 12)
#On y-axis
plt.ylabel('Average Rating', fontsize=12)
#giving a bar plot
french_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# We will consider all the neighborhoods with average rating greater or equal 8.0 to visualize on map.

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]

# %%
ny_neighborhood_stats
# Out:
#           Neighborhood  Average Rating
# 2   Bedford Stuyvesant        8.450000
# 3          Boerum Hill        8.600000
# 4     Brooklyn Heights        8.500000
# 5             Bushwick        8.250000
# 7      Carroll Gardens        8.400000
# 8       Central Harlem        8.466667
# 9              Chelsea        8.800000
# 10           Chinatown        8.600000
# 13             Clinton        8.150000
# 14        Clinton Hill        8.600000
# 15         Cobble Hill        8.500000
# 17            Downtown        8.500000
# 18         East Harlem        8.900000
# 20         Fort Greene        8.600000
# 23          Greenpoint        8.433333
# 24   Greenwich Village        9.000000
# 28          Lenox Hill        8.400000
# 29      Lincoln Square        8.640000
# 32     Lower East Side        8.850000
# 34      Manhattanville        8.600000
# 35             Midtown        9.000000
# 36         Murray Hill        8.500000
# 39          North Side        8.400000
# 42    Roosevelt Island        8.500000
# 50     Upper East Side        8.300000
# 53     Windsor Terrace        8.800000
# 54           Yorkville        8.800000

# %% [markdown]
# We will join this dataset to original new york data to get lonitude and latitude.

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')

# %%
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#           Borough       Neighborhood   Latitude  Longitude  Average Rating
# 21      Manhattan            Midtown  40.754691 -73.981669            9.00
# 16      Manhattan  Greenwich Village  40.726933 -73.999914            9.00
# 13      Manhattan        East Harlem  40.792249 -73.944182            8.90
# 19      Manhattan    Lower East Side  40.717807 -73.980890            8.85
# 28      Manhattan          Yorkville  40.775930 -73.947118            8.80
# 27       Brooklyn    Windsor Terrace  40.656946 -73.980073            8.80
# 6       Manhattan            Chelsea  40.744035 -74.003116            8.80
# 7   Staten Island            Chelsea  40.594726 -74.189560            8.80
# 18      Manhattan     Lincoln Square  40.773529 -73.985338            8.64
# 20      Manhattan     Manhattanville  40.816934 -73.957385            8.60

# %% [markdown]
# Finally, Let's show this data on a map.

# %%
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# Out:
# The geograpical coordinate of New York are 40.7127281, -74.0060152.

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %% [markdown]
# Lets add a new field to dataframe for labeling purpose.

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %% [markdown]
# Best neighbourhoods in New York that has highest average rating for French Restaurants.

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6b2d487d86ad446e8bdfc7f355438536%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6b2d487d86ad446e8bdfc7f355438536%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6b2d487d86ad446e8bdfc7f355438536%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6b2d487d86ad446e8bdfc7f355438536%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# Result

# %% [markdown]
# 1.	Manhattan, Brooklyn and Bronx are the best Borough for French cuisine and The Queens and Staten Island have few French restaurant.
# 2.	Manhattan have the best potential French Restaurant Market.
# 3.	Brooklyn has the best likes and ratings for French Restaurants.
# 4.	Both Manhattan and Brooklyn are the best place to stay if you prefer French Cuisine.

# %% [markdown]
# Result / Conclusion
#
# Manhattan, Brooklyn and Bronx have the best rated French restaurants on average. Queens and and Staten Island have the least amount of French restaurants per borough. However, of note, Greenwich Village in Manhattan is the neighborhood in all of NYC with the most French Restaurants.
#
# Based on this information, I would state that Manhattan and Bronx are the best locations for French cuisine in NYC.
# To have the best shot of success, I would open an French restaurants in Mnhattan. It has multiple neighborhoods with average ratings exceeding 8.0 of a scale of 1.0 to 10.0 and has the least number of French restaurants making competition easier than in other boroughs.
#
# Finally, I would go to "Chez Ma Tante" in Manhattan for the best French food based on 224 Likes and  9.1
# Rating.
